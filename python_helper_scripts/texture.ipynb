# %%
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import torch as torch

colourMap = plt.cm.magma 

def add_texture(x, y, kx, ky, cond=1, angle=0, centre = (10,0)):
    # TIMESTAMP = datetime.utcnow().strftime('%Y%m%d-%H%M%S-%f')
    angle = angle*np.pi/180

    x_rot = centre[0] + x*np.cos(angle) - y*np.sin(angle)
    y_rot = centre[1] + x*np.sin(angle) + y*np.cos(angle)

    z = cond*(0.5*(np.sin(kx*x_rot) + np.sin(ky*y_rot)))

    #print(np.max(z), np.min(z))
    plt.imshow(z, extent = [0,1,0,1])
    plt.colorbar()
    return

# %%
x = np.linspace(-1, 1, 1000)
y = np.linspace(-1, 1, 1000)

X, Y = np.meshgrid(x, y)

angle = 45 

k1 = np.random.uniform(1, 2, size=5) #np.linspace(1, 20, num=5)#, endpoint=False)
k2 = np.random.uniform(1, 2, size=5)

# %%
for kx, ky in zip(k1, k2):
    fig = plt.figure(figsize=((5+1)*2, 5))
    plt.suptitle(r'kx = %.4f and ky = %.4f'%(kx, ky))
    plt.subplot(1, 2, 1)
    add_texture(X, Y, kx, ky, angle=0)
    plt.title('unrotated')
    plt.subplot(1, 2, 2)
    add_texture(X, Y, kx, ky, angle=angle)
    plt.title('rotated by %s degrees'%(angle))
    fig.tight_layout()
    plt.show
